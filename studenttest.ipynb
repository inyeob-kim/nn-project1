# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn import datasets
# %run studNet.ipynb
#import instrNet 
#import studentNN
# Out:
# test_train function
# input size =  8
# The shape of initial weights
# [[ 0.17561497 -0.04888381  0.22899248  0.53847237 -0.08278572 -0.08277991
#    0.55833605  0.27132915]
#  [-0.16598426  0.19182394 -0.1638429  -0.16466033  0.08554658 -0.67644672
#   -0.60985055 -0.19879866]
#  [-0.35808988  0.11110321 -0.32103499 -0.49932476  0.51818509 -0.07982398
#    0.02387483 -0.50372455]
#  [-0.19246836  0.03921706 -0.40693768  0.13282931 -0.21235785 -0.10312931
#   -0.21273541  0.65487923]]
# [[-0.00674861 -0.52885546  0.41127246 -0.61042182]]
# The shape of initial biases
# 2
# feed forward function
# input = [[0 0]
#  [1 0]
#  [5 1]
#  [5 2]
#  [5 5]
#  [5 6]
#  [0 5]
#  [0 4]]
# done with forward function
# [[0.7322921  0.69415384]]
# RESULT for forward propagation....
# a
# [[0.7322921  0.69415384]]
# pre_activations
# [array([[ 3.27232333,  4.58403704],
#        [-3.88512487, -7.44849033],
#        [-1.2521797 , -0.55651672],
#        [-2.72390615, -0.08114986]]), array([[1.00628301, 0.81961135]])]
# activations
# [array([[0, 0],
#        [1, 0],
#        [5, 1],
#        [5, 2],
#        [5, 5],
#        [5, 6],
#        [0, 5],
#        [0, 4]]), array([[9.63467037e-01, 9.89889682e-01],
#        [2.01316531e-02, 5.81981160e-04],
#        [2.22323051e-01, 3.64353807e-01],
#        [6.15773600e-02, 4.79723662e-01]]), array([[0.7322921 , 0.69415384]])]

# %%
data = datasets.make_moons(n_samples=2500, noise=0.1)

print('The shape of data')
print(data)



X = data[0]
print(X.shape)
y = np.expand_dims(data[1], 1)
print(y.shape)

# classifying...
cond = ['red' if value==1 else 'blue' for value in y]
plt.scatter(X[:,0], X[:,1], s=1, color=cond)
plt.show()



x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.3, )

xPass = x_train.T
yPass = y_train.T
studentNet = instrNet.test_train(xPass, yPass)
#studentNet = studNet.test_train(xPass, yPass)

results = studentNet.predict(x_test.T)
print(accuracy_score(y_test.T[0], results[0]))


data = datasets.make_moons(n_samples=2500, noise=0.2)



X = data[0]
y = np.expand_dims(data[1], 1)

x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.3, )

xPass = x_train.T
yPass = y_train.T

studentNet = instrNet.test_train(xPass, yPass)
#studentNet = studNet.test_train(xPass, yPass)
results = studentNet.predict(x_test.T)
print(accuracy_score(y_test.T[0], results[0]))
# Out:
# The shape of data
# (array([[ 1.14519965, -0.02059989],
#        [ 1.16513158, -0.65784568],
#        [ 0.28691768,  1.02814934],
#        ...,
#        [ 1.06004792, -0.57855759],
#        [ 0.77708283,  0.83694649],
#        [ 0.74628984,  0.69094017]]), array([0, 1, 0, ..., 1, 0, 0], dtype=int64))
# (2500, 2)
# (2500, 1)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-32e397da815e> in <module>
#      22 xPass = x_train.T
#      23 yPass = y_train.T
# ---> 24 studentNet = instrNet.test_train(xPass, yPass)
#      25 #studentNet = studNet.test_train(xPass, yPass)
#      26
#
# NameError: name 'instrNet' is not defined
